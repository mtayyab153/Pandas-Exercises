# %%
import pandas as pd

# %%
covid_data = pd.read_csv('01-01-2021.csv')

# %% [markdown]
# # First Question:
# Calculate total **confirmed cases**, **deaths**, **recoverd** and **active cases** in each Country Region and replace null values with **zero**.

# %%
covid_data

# %%
# covid_data.fillna(0, inplace=True)
# covid_data
# Out:
#               Province_State Country_Region    Last_Update      Lat     Long_  \
# 0                    Alabama             US  1/2/2021 5:30  32.3182  -86.9023
# 1                     Alaska             US  1/2/2021 5:30  61.3707 -152.4044
# 2             American Samoa             US  1/2/2021 5:30 -14.2710 -170.1320
# 3                    Arizona             US  1/2/2021 5:30  33.7298 -111.4312
# 4                   Arkansas             US  1/2/2021 5:30  34.9697  -92.3731
# 5                 California             US  1/2/2021 5:30  36.1162 -119.6816
# 6                   Colorado             US  1/2/2021 5:30  39.0598 -105.3111
# 7                Connecticut         FRANCE  1/2/2021 5:30  41.5978  -72.7554
# 8                       Guam             US  1/2/2021 5:30  13.4443  144.7937
# 9                     Hawaii             US  1/2/2021 5:30  21.0943 -157.4983
# 10                     Idaho             US  1/2/2021 5:30  44.2405 -114.4788
# ...

# %%
total_cases = covid_data.fillna(0).groupby('Country_Region')[['Confirmed','Deaths','Recovered','Active']].sum()
total_cases
# covid_data.pivot_table(index='Country_Region', values=['Confirmed', 'Deaths', 'Recovered', 'Active'], aggfunc='sum')
# Out:
#                 Confirmed  Deaths  Recovered     Active
# Country_Region
# ENGLAND            415302    5382   397080.0    12840.0
# FINELAND           995816   37973   102968.0   854875.0
# FRANCE             185708    5995     9800.0   169913.0
# GREENLAND              49       0        0.0        0.0
# ICELAND             44409     438    42570.0     1401.0
# INDIA              265261    2623    36740.0   225898.0
# PAK                657071   16245   429017.0   211809.0
# QUEENSLAND         677589   10958        0.0        0.0
# SOUTH AFRICA       700380   13766   556106.0   130508.0
# THAI               963389   17978        0.0        0.0
# US               15492425  241486  6770910.0  4274024.0
