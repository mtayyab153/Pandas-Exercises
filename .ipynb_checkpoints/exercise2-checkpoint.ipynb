# %%
import pandas as pd

# %%
products = pd.read_csv('Diwali_Sales_Data.csv',encoding='unicode_escape')

# %%
products[products['Product_ID']=='P00000142']
# Out:
#        User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 160    1002994     Hemant  P00000142      F     36-45   42               0
# 375    1005857     Shweta  P00000142      M     46-50   50               0
# 1164   1003232    Pauline  P00000142      F     36-45   43               1
# 1891   1005264    Barbara  P00000142      F     18-25   22               0
# 1916   1002799     Adrian  P00000142      F     18-25   19               1
# 1980   1004840     Kinney  P00000142      M     46-50   50               0
# 2116   1003777     Trupti  P00000142      F     18-25   23               0
# 2162   1000623    McGrath  P00000142      F     26-35   30               0
# 2481   1001076  Armstrong  P00000142      M     26-35   34               1
# 3247   1003823     Denise  P00000142      F       55+   78               0
# 4188   1003259     Wardle  P00000142      M     18-25   18               0
# ...

# %%
products.groupby(['Product_ID','Age Group','Gender'])['User_ID'].count()
# Out:
# Product_ID  Age Group  Gender
# P00000142   18-25      F         4
#                        M         2
#             26-35      F         5
#                        M         4
#             36-45      F         2
#                                 ..
# P0099342    51-55      M         1
# P0099442    26-35      F         1
#                        M         2
#             36-45      M         1
# P0099742    0-17       F         1
# Name: User_ID, Length: 7194, dtype: int64

# %%
products.groupby(['Product_ID','Age Group'])['User_ID'].count()
# Out:
# Product_ID  Age Group
# P00000142   18-25        6
#             26-35        9
#             36-45        3
#             46-50        3
#             51-55        2
#                         ..
# P0099342    36-45        3
#             51-55        1
# P0099442    26-35        3
#             36-45        1
# P0099742    0-17         1
# Name: User_ID, Length: 5882, dtype: int64
